# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://docs.python-requests.org/en/latest/')

# %%
soup = BeautifulSoup(r.text)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Docutils 0.17.1: http://docutils.sourceforge.net/" name="generator"/>
#   <title>
#    Requests: HTTP for Humansâ¢ — Requests 2.27.1 documentation
#   </title>
#   <link href="_static/pygments.css" rel="stylesheet" type="text/css"/>
#   <link href="_static/alabaster.css" rel="stylesheet" type="text/css"/>
#   <link href="https://assets.readthedocs.org/static/css/badge_only.css" rel="stylesheet" type="text/css"/>
#   <script data-url_root="#" id="documentation_options" src="_static/documentation_options.js">
#   </script>
#   <script src="_static/jquery.js">
#   </script>
#   <script src="_static/underscore.js">
#   </script>
#   <script src="_static/doctools.js">
#   </script>
#   <script async="async" src="https://assets.readthedocs.org/static/javascript/readthedocs-doc-embed.js">
#   </script>
# ...

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
r = requests.get('https://mckinsey-2.us10.hcs.cloud.sap/')

# %%
def show_html(html):
    soup = BeautifulSoup(html)
    print(soup.prettify())

# %%
show_html(r.content)
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <!-- we should only load this content when not authenticated-->
#   <script>
#    if (window.parent === window) {
#       // the page is not loaded in an iframe
#       var currentUrl = window.location.href;
#       // e.g. https://myhost:433
#       var baseUrl = window.location.protocol + '//' + window.location.host;
#       var currentRelativeUrl = currentUrl.substring(baseUrl.length);
#       var encodedRedirectUrl = encodeURIComponent(currentRelativeUrl);
#       var redirectEndpoint = '/approuter/v1/redirect?url=' + encodedRedirectUrl;
#       window.location.href = redirectEndpoint;
#     } else {
#       var url = '/approuter/v1/embedded-auth';
#       var popupWindow;
#       window.addEventListener('message', function(event) {
#         // check event.origin
#         console.log(event.data);
#         if (popupWindow) {
#           popupWindow.close();
#           window.location.reload();
#         }
#       });
# ...

# %%
show_html(r.text)
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <!-- we should only load this content when not authenticated-->
#   <script>
#    if (window.parent === window) {
#       // the page is not loaded in an iframe
#       var currentUrl = window.location.href;
#       // e.g. https://myhost:433
#       var baseUrl = window.location.protocol + '//' + window.location.host;
#       var currentRelativeUrl = currentUrl.substring(baseUrl.length);
#       var encodedRedirectUrl = encodeURIComponent(currentRelativeUrl);
#       var redirectEndpoint = '/approuter/v1/redirect?url=' + encodedRedirectUrl;
#       window.location.href = redirectEndpoint;
#     } else {
#       var url = '/approuter/v1/embedded-auth';
#       var popupWindow;
#       window.addEventListener('message', function(event) {
#         // check event.origin
#         console.log(event.data);
#         if (popupWindow) {
#           popupWindow.close();
#           window.location.reload();
#         }
#       });
# ...

# %%
import asyncio
import pyppeteer
from pyppeteer import launch

# %%
import browsercookie
cj = browsercookie.chrome()

# %%
path = r"C:\Users\JensRottmann-Matthes\AppData\Local\Google\Chrome\User Data"

# %%
import json

# %%
import os,sys

# %%
ffpath = os.path.join(os.getenv('APPDATA',''), 'Mozilla/Firefox/profiles.ini')

# %%
import glob

# %%
find_profile = glob.glob(ffpath)

# %%
find_profile[0]
# Out:
# 'C:\\Users\\JensRottmann-Matthes\\AppData\\Roaming\\Mozilla/Firefox/profiles.ini'

# %%
import configparser

# %%
cp = configparser.ConfigParser()

# %%
cp.read(find_profile[0])
# Out:
# ['C:\\Users\\JensRottmann-Matthes\\AppData\\Roaming\\Mozilla/Firefox/profiles.ini']

# %%
os.path.dirname(find_profile[0])
# Out:
# 'C:\\Users\\JensRottmann-Matthes\\AppData\\Roaming\\Mozilla/Firefox'

# %%
cp.sections()
# Out:
# ['Install308046B0AF4A39CB', 'Profile1', 'Profile0', 'General']

# %%
for section in cp.sections():
    try:
        if cp.getboolean(section, 'IsRelative'):
            path = os.path.dirname(find_profile[0]) + '/' + cp.get(section,'Path')
        else:
            path = cp.get(section,'Path')
        if cp.has_option(section,'Default'):
            result= os.path.abspath(os.path.expanduser(path))
    except BaseException:
        pass

# %%
result
# Out:
# 'C:\\Users\\JensRottmann-Matthes\\AppData\\Roaming\\Mozilla\\Firefox\\Profiles\\5o06x7ad.default'

# %%
cookie_files= glob.glob(os.path.expanduser(path+'/cookies.sqlite'))

# %%
cookie_files
# Out:
# ['C:\\Users\\JensRottmann-Matthes\\AppData\\Roaming\\Mozilla/Firefox/Profiles/3yfuvbhk.default-release/cookies.sqlite']

# %%
import sqlite3

# %%
con = sqlite3.connect(cookie_files[0])

# %%
cur = con.cursor()

# %%
cur.execute('select host, path, isSecure, expiry, name, value from moz_cookies')

# %%
for item in cur.fetchall():
    print(item)
# Out:
# ('stadtplan.bielefeld.de', '/', 0, 1653676792, '_pk_id.58.976b', '3c44f0cdaa5ab69a.1619721592.')
# ('.testzentrum-bi.de', '/', 0, 1651257641, 'borlabs-cookie', '%7B%22consents%22%3A%7B%22essential%22%3A%5B%22borlabs-cookie%22%5D%7D%2C%22domainPath%22%3A%22testzentrum-bi.de%2F%22%2C%22expires%22%3A%22Fri%2C%2029%20Apr%202022%2018%3A40%3A41%20GMT%22%2C%22uid%22%3A%22o6iyzohw-u73ynftz-0ibc4xbm-5lr2nnvv%22%2C%22version%22%3A%221%22%7D')
# ('uni-bi.testzentren-deutschland.de', '/', 0, 1651257661, '__cookie_consent', 'true')
# ('.sap.com', '/', 1, 1653884208, 'notice_preferences', '1:')
# ('.sap.com', '/', 1, 1653884208, 'notice_gdpr_prefs', '0,1:')
# ('.sap.com', '/', 1, 1653884208, 'cmapi_gtm_bl', 'ta-asp-bzi-sp-awct-cts-csm-img-flc-fls-mpm-mpr-m6d-tc-tdc')
# ('.sap.com', '/', 1, 1653884208, 'cmapi_cookie_privacy', 'permit 1,2 functional')
# ('help.sap.com', '/', 0, 1647404209, 'ownerID', '39479164888356433_v1')
# ...

# %%
import http.cookiejar as cookielib

# %%
cookie_jar = cookielib.CookieJar()

# %%
cookie_jar
# Out:
# <CookieJar[]>

# %%
with open(path,'r') as file:
    json.loads(file.read())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [27], in <module>
# ----> 1 with open(path,'r') as file:
#       2     json.loads(file.read())
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\JensRottmann-Matthes\\AppData\\Local\\Google\\Chrome\\User Data'

# %%
r = requests.get('https://mckinsey-2.us10.hcs.cloud.sap/',cj)

# %%
passcode_url = 'https://mckinsey-2.authentication.us10.hana.ondemand.com/passcode'

# %%
r = requests.get(passcode_url)

# %%
r.headers
# Out:
# {'cache-control': 'no-cache, no-store, max-age=0, must-revalidate', 'content-language': 'en-US', 'content-type': 'text/html;charset=UTF-8', 'date': 'Wed, 23 Feb 2022 06:08:47 GMT', 'expires': '0', 'pragma': 'no-cache', 'set-cookie': 'X-Uaa-Csrf=xy6DlEj6J5MFKq5lkeX4Bb; Max-Age=86400; Expires=Thu, 24-Feb-2022 06:08:47 GMT; Path=/; Secure; HttpOnly; SameSite=None', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-vcap-request-id': 'ae6e722d-2412-4ae8-5d8c-edb716071751', 'x-xss-protection': '1; mode=block', 'transfer-encoding': 'chunked', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload;'}

# %%
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='X-Uaa-Csrf', value='xy6DlEj6J5MFKq5lkeX4Bb', port=None, port_specified=False, domain='mckinsey-2.authentication.us10.hana.ondemand.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=1645682928, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'None'}, rfc2109=False)]>

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html dir="ltr" lang="en" >\n<head>\n    \n    <title>Login</title>\n    <meta charset=\'utf-8\' />\n    <meta name=\'author\' content="SAP SE" />\n    <meta name=\'copyright\' content="Copyright \xc2\xa9 2022 SAP SE. All rights reserved." />\n    <meta name=\'robots\' content=\'all\' />\n    <meta name=\'Description\' content=""/>\n    <meta name=\'keywords\' content=""/>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0"/>\n    \n    <meta name="redirect" content="saml/discovery?returnIDParam=idp&amp;entityID=https://mckinsey-2.authentication.us10.hana.ondemand.com&amp;idp=hanacloudservices-us.accounts.ondema&amp;isPassive=true">\n        \n<script>function samlRedirect(){var link=null;var metaElements=document.getElementsByTagName(\'meta\');for(k=0;k<metaElements.length;k++){if(metaElements[k].getAttribute(\'name\')===\'redirect\'){link=metaElements[k].getAttribute(\'content\');};};if(link!=null&&link.length>0&&getQueryStringValue("origin
# ...

# %%
import beautifulsoup4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [17], in <module>
# ----> 1 import beautifulsoup4
#
# ModuleNotFoundError: No module named 'beautifulsoup4'

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" lang="en" >\n<head>\n    \n    <title>Login</title>\n    <meta charset=\'utf-8\' />\n    <meta name=\'author\' content="SAP SE" />\n    <meta name=\'copyright\' content="Copyright © 2022 SAP SE. All rights reserved." />\n    <meta name=\'robots\' content=\'all\' />\n    <meta name=\'Description\' content=""/>\n    <meta name=\'keywords\' content=""/>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0"/>\n    \n    <meta name="redirect" content="saml/discovery?returnIDParam=idp&amp;entityID=https://mckinsey-2.authentication.us10.hana.ondemand.com&amp;idp=hanacloudservices-us.accounts.ondema&amp;isPassive=true">\n        \n<script>function samlRedirect(){var link=null;var metaElements=document.getElementsByTagName(\'meta\');for(k=0;k<metaElements.length;k++){if(metaElements[k].getAttribute(\'name\')===\'redirect\'){link=metaElements[k].getAttribute(\'content\');};};if(link!=null&&link.length>0&&getQueryStringValue("origin")!=="ua
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <title>Login</title>
# <meta charset="utf-8"/>
# <meta content="SAP SE" name="author"/>
# <meta content="Copyright © 2022 SAP SE. All rights reserved." name="copyright"/>
# <meta content="all" name="robots"/>
# <meta content="" name="Description"/>
# <meta content="" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="saml/discovery?returnIDParam=idp&amp;entityID=https://mckinsey-2.authentication.us10.hana.ondemand.com&amp;idp=hanacloudservices-us.accounts.ondema&amp;isPassive=true" name="redirect"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <title>
#    Login
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="SAP SE" name="author"/>
#   <meta content="Copyright © 2022 SAP SE. All rights reserved." name="copyright"/>
#   <meta content="all" name="robots"/>
#   <meta content="" name="Description"/>
#   <meta content="" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="saml/discovery?returnIDParam=idp&amp;entityID=https://mckinsey-2.authentication.us10.hana.ondemand.com&amp;idp=hanacloudservices-us.accounts.ondema&amp;isPassive=true" name="redirect"/>
#   <script>
# ...

# %% [markdown]
# # Pyppeteer
# Dies funktioniert nicht in Jupyter-Notebooks, da die "async-Funktionalität" nicht zur Verfügung steht.
